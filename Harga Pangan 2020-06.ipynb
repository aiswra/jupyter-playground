# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %matplotlib inline

# %% [markdown]
# data source = https://hargapangan.id/tabel-harga/pasar-tradisional/daerah

# %%
df = pd.read_csv("data/lh-hargapangan-jakarta.csv", skiprows=[0,1,2,3,4,5,6,7])
df.head(3)
# Out:
#   No.                 Komoditas(Rp)  02/01/2020  03/01/2020  06/01/2020  \
# 0   I                         Beras   Rp12,750    Rp12,850    Rp13,000
# 1   1   Beras Kualitas Bawah I (kg)   Rp11,550    Rp11,650    Rp11,850
# 2   2  Beras Kualitas Bawah II (kg)   Rp10,750    Rp10,850    Rp11,050
#
#    07/01/2020  08/01/2020  09/01/2020  10/01/2020  13/01/2020  ...  \
# 0   Rp13,050    Rp13,050    Rp13,050    Rp13,050    Rp13,050   ...
# 1   Rp11,900    Rp11,900    Rp11,950    Rp11,950    Rp11,950   ...
# 2   Rp11,050    Rp11,050    Rp11,100    Rp11,100    Rp11,100   ...
#
#    08/06/2020  09/06/2020  10/06/2020  11/06/2020  12/06/2020  15/06/2020  \
# 0   Rp13,500    Rp13,500    Rp13,500    Rp13,500    Rp13,500    Rp13,500
# 1   Rp12,200    Rp12,200    Rp12,200    Rp12,200    Rp12,200    Rp12,200
# 2   Rp11,400    Rp11,400    Rp11,400    Rp11,400    Rp11,400    Rp11,400
#
#    16/06/2020  17/06/2020  18/06/2020  19/06/2020
# 0   Rp13,500    Rp13,500    Rp13,500    Rp13,500
# ...

# %%
# Remove No column
df.drop(['No.'], axis=1, inplace=True)

# Rename colummn
df.rename(columns={"Komoditas(Rp)": "komoditas"}, inplace=True)

df.head(3)
# Out:
#                       komoditas  02/01/2020  03/01/2020  06/01/2020  \
# 0                         Beras   Rp12,750    Rp12,850    Rp13,000
# 1   Beras Kualitas Bawah I (kg)   Rp11,550    Rp11,650    Rp11,850
# 2  Beras Kualitas Bawah II (kg)   Rp10,750    Rp10,850    Rp11,050
#
#    07/01/2020  08/01/2020  09/01/2020  10/01/2020  13/01/2020  14/01/2020  \
# 0   Rp13,050    Rp13,050    Rp13,050    Rp13,050    Rp13,050    Rp13,050
# 1   Rp11,900    Rp11,900    Rp11,950    Rp11,950    Rp11,950    Rp11,950
# 2   Rp11,050    Rp11,050    Rp11,100    Rp11,100    Rp11,100    Rp11,100
#
#    ...  08/06/2020  09/06/2020  10/06/2020  11/06/2020  12/06/2020  \
# 0  ...   Rp13,500    Rp13,500    Rp13,500    Rp13,500    Rp13,500
# 1  ...   Rp12,200    Rp12,200    Rp12,200    Rp12,200    Rp12,200
# 2  ...   Rp11,400    Rp11,400    Rp11,400    Rp11,400    Rp11,400
#
#    15/06/2020  16/06/2020  17/06/2020  18/06/2020  19/06/2020
# 0   Rp13,500    Rp13,500    Rp13,500    Rp13,500    Rp13,500
# ...

# %%
# Format value
date_cols = df.columns.to_list()
date_cols = date_cols[1:]

print(date_cols)
# Out:
# ['02/01/2020', '03/01/2020', '06/01/2020', '07/01/2020', '08/01/2020', '09/01/2020', '10/01/2020', '13/01/2020', '14/01/2020', '15/01/2020', '16/01/2020', '17/01/2020', '20/01/2020', '21/01/2020', '22/01/2020', '23/01/2020', '24/01/2020', '27/01/2020', '28/01/2020', '29/01/2020', '30/01/2020', '31/01/2020', '03/02/2020', '04/02/2020', '05/02/2020', '06/02/2020', '07/02/2020', '10/02/2020', '11/02/2020', '12/02/2020', '13/02/2020', '14/02/2020', '17/02/2020', '18/02/2020', '19/02/2020', '20/02/2020', '21/02/2020', '24/02/2020', '25/02/2020', '26/02/2020', '27/02/2020', '28/02/2020', '02/03/2020', '03/03/2020', '04/03/2020', '05/03/2020', '06/03/2020', '09/03/2020', '10/03/2020', '11/03/2020', '12/03/2020', '13/03/2020', '16/03/2020', '17/03/2020', '18/03/2020', '19/03/2020', '20/03/2020', '23/03/2020', '24/03/2020', '26/03/2020', '27/03/2020', '30/03/2020', '31/03/2020', '01/04/2020', '02/04/2020', '03/04/2020', '06/04/2020', '07/04/2020', '08/04/2020', '09/04/2020', '13/04/2020', '14
# ...

# %%
for i in date_cols:
    df[i] = df[i].str.extract('(\d+,\d+)', expand=False).replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df.head(3)
# Out:
#                       komoditas  02/01/2020  03/01/2020  06/01/2020  \
# 0                         Beras       12750       12850       13000
# 1   Beras Kualitas Bawah I (kg)       11550       11650       11850
# 2  Beras Kualitas Bawah II (kg)       10750       10850       11050
#
#    07/01/2020  08/01/2020  09/01/2020  10/01/2020  13/01/2020  14/01/2020  \
# 0       13050       13050       13050       13050       13050       13050
# 1       11900       11900       11950       11950       11950       11950
# 2       11050       11050       11100       11100       11100       11100
#
#    ...  08/06/2020  09/06/2020  10/06/2020  11/06/2020  12/06/2020  \
# 0  ...       13500       13500       13500       13500       13500
# 1  ...       12200       12200       12200       12200       12200
# 2  ...       11400       11400       11400       11400       11400
#
#    15/06/2020  16/06/2020  17/06/2020  18/06/2020  19/06/2020
# ...

# %%
# Add commodity name col
df['komoditas'].unique()
# Out:
# array(['Beras', 'Beras Kualitas Bawah I (kg)',
#        'Beras Kualitas Bawah II (kg)', 'Beras Kualitas Medium I (kg)',
#        'Beras Kualitas Medium II (kg)', 'Beras Kualitas Super I (kg)',
#        'Beras Kualitas Super II (kg)', 'Daging Ayam',
#        'Daging Ayam Ras Segar (kg)', 'Daging Sapi',
#        'Daging Sapi Kualitas 1 (kg)', 'Daging Sapi Kualitas 2 (kg)',
#        'Telur Ayam', 'Telur Ayam Ras Segar\n (kg)', 'Bawang Merah',
#        'Bawang Merah Ukuran Sedang (kg)', 'Bawang Putih',
#        'Bawang Putih Ukuran Sedang (kg)', 'Cabai Merah',
#        'Cabai Merah Besar (kg)', 'Cabai Merah Keriting  (kg)',
#        'Cabai Rawit', 'Cabai Rawit Hijau (kg)', 'Cabai Rawit Merah (kg)',
#        'Minyak Goreng', 'Minyak Goreng Curah (kg)',
#        'Minyak Goreng Kemasan Bermerk 1 (kg)',
#        'Minyak Goreng Kemasan Bermerk 2 (kg)', 'Gula Pasir',
#        'Gula Pasir Kualitas Premium (kg)', 'Gula Pasir Lokal (kg)'],
#       dtype=object)

# %%
list_komoditas = ['Beras', 'Daging Ayam','Daging Sapi','Telur Ayam',  'Bawang Merah','Bawang Putih','Cabai Merah', 'Cabai Rawit', 'Minyak Goreng',  'Gula Pasir']
len(list_komoditas)
# Out:
# 10

# %%
def getCommodityType(x):
    for i in list_komoditas:
        if i in x:
            return i

# %%
df['tipe_komoditas'] = df['komoditas'].apply(lambda x: getCommodityType(x))
df.head(3)
# Out:
#                       komoditas  02/01/2020  03/01/2020  06/01/2020  \
# 0                         Beras       12750       12850       13000
# 1   Beras Kualitas Bawah I (kg)       11550       11650       11850
# 2  Beras Kualitas Bawah II (kg)       10750       10850       11050
#
#    07/01/2020  08/01/2020  09/01/2020  10/01/2020  13/01/2020  14/01/2020  \
# 0       13050       13050       13050       13050       13050       13050
# 1       11900       11900       11950       11950       11950       11950
# 2       11050       11050       11100       11100       11100       11100
#
#    ...  09/06/2020  10/06/2020  11/06/2020  12/06/2020  15/06/2020  \
# 0  ...       13500       13500       13500       13500       13500
# 1  ...       12200       12200       12200       12200       12200
# 2  ...       11400       11400       11400       11400       11400
#
#    16/06/2020  17/06/2020  18/06/2020  19/06/2020  tipe_komoditas
# ...

# %%
date_list = df.columns.to_list()
date_list.remove('komoditas')
date_list.remove('tipe_komoditas')
date_list
# Out:
# ['02/01/2020',
#  '03/01/2020',
#  '06/01/2020',
#  '07/01/2020',
#  '08/01/2020',
#  '09/01/2020',
#  '10/01/2020',
#  '13/01/2020',
#  '14/01/2020',
#  '15/01/2020',
#  '16/01/2020',
#  '17/01/2020',
#  '20/01/2020',
#  '21/01/2020',
#  '22/01/2020',
#  '23/01/2020',
#  '24/01/2020',
#  '27/01/2020',
#  '28/01/2020',
#  '29/01/2020',
#  '30/01/2020',
#  '31/01/2020',
#  '03/02/2020',
#  '04/02/2020',
#  '05/02/2020',
#  '06/02/2020',
#  '07/02/2020',
#  '10/02/2020',
#  '11/02/2020',
#  '12/02/2020',
#  '13/02/2020',
#  '14/02/2020',
#  '17/02/2020',
#  '18/02/2020',
#  '19/02/2020',
#  '20/02/2020',
#  '21/02/2020',
#  '24/02/2020',
#  '25/02/2020',
#  '26/02/2020',
#  '27/02/2020',
#  '28/02/2020',
#  '02/03/2020',
#  '03/03/2020',
#  '04/03/2020',
#  '05/03/2020',
#  '06/03/2020',
#  '09/03/2020',
#  '10/03/2020',
#  '11/03/2020',
#  '12/03/2020',
#  '13/03/2020',
#  '16/03/2020',
#  '17/03/2020',
#  '18/03/2020',
#  '19/03/2020',
#  '20/03/2020',
#  '23/03/2020',
# ...

# %%
dftemp =pd.melt(df, id_vars =['tipe_komoditas', 'komoditas'], value_vars = date_list)

# %%
dftemp['date'] = pd.to_datetime(dftemp['variable'], format = '%d/%m/%Y')
dftemp.head(3)
# Out:
#   tipe_komoditas                     komoditas    variable  value       date
# 0          Beras                         Beras  02/01/2020  12750 2020-01-02
# 1          Beras   Beras Kualitas Bawah I (kg)  02/01/2020  11550 2020-01-02
# 2          Beras  Beras Kualitas Bawah II (kg)  02/01/2020  10750 2020-01-02

# %%
# Plot - average

df_agg_type = dftemp.groupby(['tipe_komoditas','date'])['value'].mean().reset_index()

df_agg_type.head(2)
# Out:
#   tipe_komoditas       date    value
# 0   Bawang Merah 2020-01-02  46650.0
# 1   Bawang Merah 2020-01-03  46650.0

# %%
list_tipe_komoditas = df_agg_type.tipe_komoditas.unique()
col_count = 1
row_count = 1
fig = make_subplots(
    rows=5, cols=2,
    subplot_titles=tuple(list_tipe_komoditas))

for i in list_tipe_komoditas:
    dft = df_agg_type.query('tipe_komoditas == "{}"'.format(i))
    fig.add_trace(go.Scatter(x=dft.date, y=dft.value,name = i),
              row=row_count, col=col_count)
    col_count +=1
    if col_count>2 : 
        col_count = 1
        row_count +=1
        if row_count>5 :
            row_count = 1


fig.update_layout(height=1400, width=1000,
                  title_text="Harga Pangan per Kg YTD")

fig.show()
# Out:
# <div>
#
#
#             <div id="faa44a46-8f9a-4348-974c-0ad61b5babb7" class="plotly-graph-div" style="height:1400px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("faa44a46-8f9a-4348-974c-0ad61b5babb7")) {
#                     Plotly.newPlot(
#                         'faa44a46-8f9a-4348-974c-0ad61b5babb7',
# ...

# %%
dftemp.head(5)
# Out:
#   tipe_komoditas                      komoditas    variable  value       date
# 0          Beras                          Beras  02/01/2020  12750 2020-01-02
# 1          Beras    Beras Kualitas Bawah I (kg)  02/01/2020  11550 2020-01-02
# 2          Beras   Beras Kualitas Bawah II (kg)  02/01/2020  10750 2020-01-02
# 3          Beras   Beras Kualitas Medium I (kg)  02/01/2020  13050 2020-01-02
# 4          Beras  Beras Kualitas Medium II (kg)  02/01/2020  12050 2020-01-02

# %%
list_tipe_komoditas
# Out:
# array(['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',
#        'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',
#        'Minyak Goreng', 'Gula Pasir'], dtype=object)

# %%
list_tipe_komoditas = dftemp.tipe_komoditas.unique()
col_count = 1
row_count = 1
fig = make_subplots(
    rows=5, cols=2,
    subplot_titles=tuple(list_tipe_komoditas))

for i in list_tipe_komoditas:
    dft = dftemp.query('tipe_komoditas == "{}"'.format(i))
    list_komoditas = dft.komoditas.unique()
    for l in list_komoditas:
        dft_komoditas = dft[dft.komoditas==l]
        fig.add_trace(go.Scatter(x=dft_komoditas.date, y=dft_komoditas.value,name = l),
          row=row_count, col=col_count)
    col_count +=1
    if col_count>2 : 
        col_count = 1
        row_count +=1
        if row_count>5 :
            row_count = 1


fig.update_layout(height=1400, width=1000,
                  title_text="Harga Pangan per Kg YTD")

fig.show()
# Out:
# <div>
#
#
#             <div id="cdb3aba5-b5ce-44c8-9b3c-32bbf220ac8e" class="plotly-graph-div" style="height:1400px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cdb3aba5-b5ce-44c8-9b3c-32bbf220ac8e")) {
#                     Plotly.newPlot(
#                         'cdb3aba5-b5ce-44c8-9b3c-32bbf220ac8e',
# ...
